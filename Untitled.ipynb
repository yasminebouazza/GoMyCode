# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:/Users/yessm/Desktop/StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
import seaborn as sns, numpy as np
plt.title("Histogram of different score math") 
plt.xlabel("math score")
df['math score'].plot.hist()
sns.displot(df["math score"],bins=10,kde=True , color="red")

# %%
plt.title("Histogram of diffrent writing score")
plt.xlabel("writing score")
df['writing score'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of diffrent writing score'}, xlabel='writing score', ylabel='Frequency'>

# %%
plt.xlabel("parental level of education")
plt.ylabel("parental value count")
plt.title("bar plot of parental level of education")
vc=df['parental level of education'].value_counts()
vc.plot.bar(rot=45)
# Out:
# <AxesSubplot:title={'center':'bar plot of parental level of education'}, xlabel='parental level of education', ylabel='parental value count'>
