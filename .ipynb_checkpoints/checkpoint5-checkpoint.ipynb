# %%
import pandas as pd
df = pd.read_csv("C:/Users/yessm/Downloads/titanic-passengers.csv",delimiter=';')
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
#Remplacer les valeurs null dans Age par la moyenne des age 
df['Age'].fillna(df['Age'].median(), inplace=True)
#Remplacer les valeurs null dans Cabin par 'G23' la valeur la plus fréquente 
nb = len(df["Cabin"])
print("number of element:" , nb)
print(df["Cabin"].value_counts())
df["Cabin"].fillna('G23',inplace=True)
#Remplacer les valeurs null dans Embarked par S la valeur la plus fréquente 
nb2 = len(df["Embarked"])
print("number of element:" , nb2)
print(df["Embarked"].value_counts())
df["Embarked"].fillna('S',inplace=True)
# Out:
# number of element: 891
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F2             3
#               ..
# D21            1
# D9             1
# A16            1
# D56            1
# A31            1
# Name: Cabin, Length: 147, dtype: int64
# number of element: 891
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
def get_title(txt):
 title=txt[txt.find(",")+2:txt.find(".")]
 return title

# %%
df["Title"]=df["Name"].apply(get_title)
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked Title
# 0    male  28.0      0      0      248740  13.0000    G23        S    Mr
# 1    male  25.0      0      0      348123   7.6500  F G73        S    Mr
# 2    male  20.0      0      0      350050   7.8542    G23        S    Mr
# 3  female  29.0      0      4      349909  21.0750    G23        S   Mrs
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S    Mr

# %%
df["Survived"]=df["Survived"].map({"Yes": 1, "No": 0})
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked Title
# 0    male  28.0      0      0      248740  13.0000    G23        S    Mr
# 1    male  25.0      0      0      348123   7.6500  F G73        S    Mr
# 2    male  20.0      0      0      350050   7.8542    G23        S    Mr
# 3  female  29.0      0      4      349909  21.0750    G23        S   Mrs
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S    Mr

# %%
print(df["Embarked"].value_counts())
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
one_hot =pd.get_dummies(df['Embarked'])
df=df.drop('Embarked',axis = 1)
df=df.join(one_hot)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  28.0      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Title  C  Q  S
# 0        0      248740  13.0000    G23    Mr  0  0  1
# 1        0      348123   7.6500  F G73    Mr  0  0  1
# 2        0      350050   7.8542    G23    Mr  0  0  1
# 3        4      349909  21.0750    G23   Mrs  0  0  1
# 4        0  F.C. 12750  52.0000    B71    Mr  0  0  1
# ..     ...         ...      ...    ...   ... .. .. ..
# 886      0      237736  30.0708    G23   Mrs  1  0  0
# 887      0        2669   7.2292    G23    Mr  1  0  0
# 888      0      315084   8.6625    G23  Miss  0  0  1
# 889      0      349215   7.8958    G23    Mr  0  0  1
# 890      0      250655  26.0000    G23  Miss  0  0  1
#
# [891 rows x 15 columns]

# %%
df["Sex"]=df["Sex"].map({"female": 1, "male": 0})
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    0  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    0  25.0      0
# 2                               Jensen, Mr. Hans Peder    0  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    1  29.0      0
# 4                               Davidson, Mr. Thornton    0  31.0      1
# ..                                                 ...  ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1
# 887                              Sirayanian, Mr. Orsen    0  22.0      0
# 888                                Cacic, Miss. Marija    1  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    0  28.0      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    1  19.0      0
#
#      Parch      Ticket     Fare  Cabin Title  C  Q  S
# 0        0      248740  13.0000    G23    Mr  0  0  1
# 1        0      348123   7.6500  F G73    Mr  0  0  1
# 2        0      350050   7.8542    G23    Mr  0  0  1
# 3        4      349909  21.0750    G23   Mrs  0  0  1
# 4        0  F.C. 12750  52.0000    B71    Mr  0  0  1
# ..     ...         ...      ...    ...   ... .. .. ..
# 886      0      237736  30.0708    G23   Mrs  1  0  0
# 887      0        2669   7.2292    G23    Mr  1  0  0
# 888      0      315084   8.6625    G23  Miss  0  0  1
# 889      0      349215   7.8958    G23    Mr  0  0  1
# 890      0      250655  26.0000    G23  Miss  0  0  1
#
# [891 rows x 15 columns]

# %%
#import relevant libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

#features extraction
x = df[['C','Q','S', 'Sex','Age']]
y = df['Survived']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)  #splitting data with test size of 25%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.83

# %%
import seaborn as sns
sns.regplot(x='Age',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>
