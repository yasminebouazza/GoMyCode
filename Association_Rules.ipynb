# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import pandas as pd
import seaborn as sns
import numpy as np

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
te = TransactionEncoder()
te_aray=te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_aray,columns=te.columns_)
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
#support with column names 
frequent_itemsets=apriori(df,min_support=0.5,use_colnames=True)
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)

# %%
#Cofindence 
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 1     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        0.75  1.2500      0.12         1.6
# 3        1.00  1.2500      0.12         inf

# %%
from math import isnan
d = pd.read_csv('C:/Users/yessm/Downloads/Market_Basket_Optimisation.csv')
d
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
dict = pd.unique(d.values.ravel())
dict
# Out:
# array(['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes',
#        'whole weat flour', 'yams', 'cottage cheese', 'energy drink',
#        'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad',
#        'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie',
#        'spinach', 'olive oil', 'burgers', 'meatballs', 'eggs', nan,
#        'chutney', 'turkey', 'milk', 'energy bar', 'whole wheat rice',
#        'whole wheat pasta', 'french fries', 'soup', 'light cream',
#        'shallot', 'frozen vegetables', 'spaghetti', 'pet food', 'cookies',
#        'cooking oil', 'champagne', 'chocolate', 'chicken', 'oil',
#        'fresh tuna', 'tomatoes', 'black tea', 'extra dark chocolate',
#        'protein bar', 'red wine', 'pasta', 'pepper', 'shampoo', 'rice',
#        'sparkling water', 'ham', 'body spray', 'pancakes',
#        'grated cheese', 'white wine', 'toothpaste', 'parmesan cheese',
#        'fresh bread', 'ground beef', 'escalope', 'herb & pepper',
# ...

# %%
d.isnull().sum()
# Out:
# shrimp                  0
# almonds              1754
# avocado              3112
# vegetables mix       4156
# green grapes         4972
# whole weat flour     5637
# yams                 6132
# cottage cheese       6520
# energy drink         6847
# tomato juice         7106
# low fat yogurt       7245
# green tea            7347
# honey                7414
# salad                7454
# mineral water        7476
# salmon               7493
# antioxydant juice    7497
# frozen smoothie      7497
# spinach              7498
# olive oil            7500
# dtype: int64

# %%
d.replace(np.nan,"hriisa", inplace=True)
d = np.array(d)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
te_aray=te.fit(d).transform(d)
df = pd.DataFrame(te_aray,columns=te.columns_)
frequent_itemsets=apriori(df,min_support=0.01,use_colnames=True)
association_rules(frequent_itemsets, metric="confidence",min_threshold=0.2)
# Out:
#                               antecedents              consequents  \
# 0                               (almonds)                 (hriisa)
# 1                               (avocado)                 (hriisa)
# 2                               (avocado)          (mineral water)
# 3                        (barbecue sauce)                 (hriisa)
# 4                             (black tea)                 (hriisa)
# ..                                    ...                      ...
# 741  (pancakes, spaghetti, mineral water)                 (hriisa)
# 742         (pancakes, spaghetti, hriisa)          (mineral water)
# 743     (pancakes, mineral water, hriisa)              (spaghetti)
# 744                 (pancakes, spaghetti)  (mineral water, hriisa)
# 745             (pancakes, mineral water)      (spaghetti, hriisa)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.020267            1.000000  0.020267    1.000000  1.000000
# ...

# %%
association_rules(frequent_itemsets, metric="lift",min_threshold=0.6)
# Out:
#                   antecedents                           consequents  \
# 0                   (almonds)                              (hriisa)
# 1                    (hriisa)                             (almonds)
# 2                   (avocado)                              (hriisa)
# 3                    (hriisa)                             (avocado)
# 4                   (avocado)                       (mineral water)
# ...                       ...                                   ...
# 1821  (mineral water, hriisa)                 (pancakes, spaghetti)
# 1822               (pancakes)    (spaghetti, mineral water, hriisa)
# 1823              (spaghetti)     (pancakes, mineral water, hriisa)
# 1824          (mineral water)         (pancakes, spaghetti, hriisa)
# 1825                 (hriisa)  (pancakes, spaghetti, mineral water)
#
#       antecedent support  consequent support   support  confidence      lift  \
# ...
